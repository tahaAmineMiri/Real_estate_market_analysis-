# %%
import pandas as pd
import numpy as np

# %%
# 1. Load the datasets
properties_raw_data = pd.read_csv('properties.csv', index_col = 0)
customers_raw_data = pd.read_csv('customers.csv', index_col = 0)

# %% [markdown]
# ## Discover the content of the dataframes

# %%
properties_raw_data.dtypes
# Out:
# id             int64
# building        int64
# date_sale      object
# type           object
# property#       int64
# area          float64
# price          object
# status         object
# customerid     object
# dtype: object

# %%
customers_raw_data.dtypes
# Out:
# customerid          object
# entity               object
# name                 object
# surname              object
# birth_date           object
# sex                  object
# country              object
# state                object
# purpose              object
# deal_satisfaction     int64
# mortgage             object
# source               object
# dtype: object

# %% [markdown]
# ## Cleaning and preparing the data

# %% [markdown]
# ## Properties Dataset

# %%
properties = properties_raw_data.copy()

# %%
properties.describe(include='all')
# Out:
#                 ﻿id    building date_sale       type   property#         area  \
# count    267.000000  267.000000       267        267  267.000000   267.000000
# unique          NaN         NaN        44          2         NaN          NaN
# top             NaN         NaN     #NUM!  Apartment         NaN          NaN
# freq            NaN         NaN        72        259         NaN          NaN
# mean    2975.142322    2.947566       NaN        NaN   27.580524   936.221311
# std     1392.197474    1.391794       NaN        NaN   15.361437   284.894858
# min     1002.000000    1.000000       NaN        NaN    1.000000   410.710000
# 25%     2015.500000    2.000000       NaN        NaN   14.500000   756.210000
# 50%     3024.000000    3.000000       NaN        NaN   28.000000   798.280000
# 75%     4031.500000    4.000000       NaN        NaN   40.000000  1121.950000
# max     5052.000000    5.000000       NaN        NaN   59.000000  1942.500000
#
#                price  status customerid
# count            267     267        195
# unique           266       2        162
# top     $460,001.26    Sold      C0174
# freq               2     195          9
# mean             NaN     NaN        NaN
# std              NaN     NaN        NaN
# min              NaN     NaN        NaN
# 25%              NaN     NaN        NaN
# 50%              NaN     NaN        NaN
# 75%              NaN     NaN        NaN
# max              NaN     NaN        NaN

# %%
properties.dtypes
# Out:
# id             int64
# building        int64
# date_sale      object
# type           object
# property#       int64
# area          float64
# price          object
# status         object
# customerid     object
# dtype: object

# %%
properties.columns.array
# Out:
# <NumpyExtensionArray>
# [  '\ufeffid',   'building',  'date_sale',       'type',  'property#',
#        'area',      'price',     'status', 'customerid']
# Length: 9, dtype: object

# %%
properties = properties.rename(columns = {'\ufeffid': 'id'})
properties.head(3)
# Out:
#      id  building  date_sale       type  property#    area         price  \
# 0  1030         1  11/1/2005  Apartment         30  743.09  $246,172.68
# 1  1029         1  10/1/2005  Apartment         29  756.21  $246,331.90
# 2  2002         2   7/1/2007  Apartment          2  587.28  $209,280.91
#
#    status customerid
# 0   Sold      C0028
# 1   Sold      C0027
# 2   Sold      C0112

# %%
# change the id type into a string 
properties['id'] = properties['id'].astype(str)

# change the building and property# type into a string
properties['building'] = properties['building'].astype(str)
properties['property#'] = properties['property#'].astype(str)

# examine the type
properties.dtypes
# Out:
# id             object
# building       object
# date_sale      object
# type           object
# property#      object
# area          float64
# price          object
# status         object
# customerid     object
# dtype: object

# %%
properties.describe(include='all')
# Out:
#           id building date_sale       type property#         area  \
# count    267      267       267        267       267   267.000000
# unique   240        5        44          2        59          NaN
# top     5041        3     #NUM!  Apartment        34          NaN
# freq       2       63        72        259         7          NaN
# mean     NaN      NaN       NaN        NaN       NaN   936.221311
# std      NaN      NaN       NaN        NaN       NaN   284.894858
# min      NaN      NaN       NaN        NaN       NaN   410.710000
# 25%      NaN      NaN       NaN        NaN       NaN   756.210000
# 50%      NaN      NaN       NaN        NaN       NaN   798.280000
# 75%      NaN      NaN       NaN        NaN       NaN  1121.950000
# max      NaN      NaN       NaN        NaN       NaN  1942.500000
#
#                price  status customerid
# count            267     267        195
# unique           266       2        162
# top     $460,001.26    Sold      C0174
# freq               2     195          9
# mean             NaN     NaN        NaN
# std              NaN     NaN        NaN
# min              NaN     NaN        NaN
# 25%              NaN     NaN        NaN
# 50%              NaN     NaN        NaN
# 75%              NaN     NaN        NaN
# max              NaN     NaN        NaN

# %%
properties['date_sale'].unique()
# Out:
# array(['11/1/2005', '10/1/2005', '7/1/2007', '12/1/2007', '11/1/2004',
#        '9/1/2007', '1/1/2008', '6/1/2006', '3/1/2006', '10/1/2004',
#        '8/1/2006', '10/1/2007', '11/1/2006', '4/1/2007', '10/1/2006',
#        '12/1/2006', '3/1/2005', '3/1/2007', '9/1/2006', '1/1/2007',
#        '5/1/2007', '7/1/2006', '5/1/2008', '11/1/2007', '1/1/2005',
#        '8/1/2007', '6/1/2005', '2/1/2007', '6/1/2007', '2/1/2005',
#        '8/1/2004', '12/1/2008', '5/1/2010', '4/1/2006', '8/1/2005',
#        '6/1/2004', '12/1/2005', '3/1/2004', '2/1/2006', '4/1/2005',
#        '5/1/2006', '#NUM!', '9/1/2005', '7/1/2005'], dtype=object)

# %%
# Replace where the values are #NUM! in date_sale with pd.NA
properties['date_sale'] = properties['date_sale'].replace('#NUM!', pd.NA)

# %%
properties['date_sale'].unique()
# Out:
# array(['11/1/2005', '10/1/2005', '7/1/2007', '12/1/2007', '11/1/2004',
#        '9/1/2007', '1/1/2008', '6/1/2006', '3/1/2006', '10/1/2004',
#        '8/1/2006', '10/1/2007', '11/1/2006', '4/1/2007', '10/1/2006',
#        '12/1/2006', '3/1/2005', '3/1/2007', '9/1/2006', '1/1/2007',
#        '5/1/2007', '7/1/2006', '5/1/2008', '11/1/2007', '1/1/2005',
#        '8/1/2007', '6/1/2005', '2/1/2007', '6/1/2007', '2/1/2005',
#        '8/1/2004', '12/1/2008', '5/1/2010', '4/1/2006', '8/1/2005',
#        '6/1/2004', '12/1/2005', '3/1/2004', '2/1/2006', '4/1/2005',
#        '5/1/2006', <NA>, '9/1/2005', '7/1/2005'], dtype=object)

# %%
# convert the date_sale into datetime
properties['date_sale'] = pd.to_datetime(properties['date_sale'])

# check the column
properties['date_sale'].unique()
# Out:
# <DatetimeArray>
# ['2005-11-01 00:00:00', '2005-10-01 00:00:00', '2007-07-01 00:00:00',
#  '2007-12-01 00:00:00', '2004-11-01 00:00:00', '2007-09-01 00:00:00',
#  '2008-01-01 00:00:00', '2006-06-01 00:00:00', '2006-03-01 00:00:00',
#  '2004-10-01 00:00:00', '2006-08-01 00:00:00', '2007-10-01 00:00:00',
#  '2006-11-01 00:00:00', '2007-04-01 00:00:00', '2006-10-01 00:00:00',
#  '2006-12-01 00:00:00', '2005-03-01 00:00:00', '2007-03-01 00:00:00',
#  '2006-09-01 00:00:00', '2007-01-01 00:00:00', '2007-05-01 00:00:00',
#  '2006-07-01 00:00:00', '2008-05-01 00:00:00', '2007-11-01 00:00:00',
#  '2005-01-01 00:00:00', '2007-08-01 00:00:00', '2005-06-01 00:00:00',
#  '2007-02-01 00:00:00', '2007-06-01 00:00:00', '2005-02-01 00:00:00',
#  '2004-08-01 00:00:00', '2008-12-01 00:00:00', '2010-05-01 00:00:00',
#  '2006-04-01 00:00:00', '2005-08-01 00:00:00', '2004-06-01 00:00:00',
#  '2005-12-01 00:00:00', '2004-03-01 00:00:00', '2006-02-01 00:00:00',
#  '2005-04-01 00:00:00', '2006-05-01 00:00:00',                 'NaT',
#  '2005-09-01 00:00:00', '2005-07-01 00:00:00']
# Length: 44, dtype: datetime64[ns]

# %%
properties.describe(include='all')
# Out:
#           id building                      date_sale       type property#  \
# count    267      267                            195        267       267
# unique   240        5                            NaN          2        59
# top     5041        3                            NaN  Apartment        34
# freq       2       63                            NaN        259         7
# mean     NaN      NaN  2006-11-08 14:38:46.153846272        NaN       NaN
# min      NaN      NaN            2004-03-01 00:00:00        NaN       NaN
# 25%      NaN      NaN            2006-04-16 00:00:00        NaN       NaN
# 50%      NaN      NaN            2007-03-01 00:00:00        NaN       NaN
# 75%      NaN      NaN            2007-09-01 00:00:00        NaN       NaN
# max      NaN      NaN            2010-05-01 00:00:00        NaN       NaN
# std      NaN      NaN                            NaN        NaN       NaN
#
#                area         price  status customerid
# count    267.000000           267     267        195
# unique          NaN           266       2        162
# top             NaN  $460,001.26    Sold      C0174
# freq            NaN             2     195          9
# mean     936.221311           NaN     NaN        NaN
# min      410.710000           NaN     NaN        NaN
# 25%      756.210000           NaN     NaN        NaN
# 50%      798.280000           NaN     NaN        NaN
# 75%     1121.950000           NaN     NaN        NaN
# max     1942.500000           NaN     NaN        NaN
# std      284.894858           NaN     NaN        NaN

# %%
properties['type'].unique()
# Out:
# array(['Apartment', 'Office'], dtype=object)

# %%
# convert to lower case the type column 
properties['type'] = properties['type'].str.lower()

# %%
properties['type'].unique()
# Out:
# array(['apartment', 'office'], dtype=object)

# %%
properties.head(3)
# Out:
#      id building  date_sale       type property#    area         price  \
# 0  1030        1 2005-11-01  apartment        30  743.09  $246,172.68
# 1  1029        1 2005-10-01  apartment        29  756.21  $246,331.90
# 2  2002        2 2007-07-01  apartment         2  587.28  $209,280.91
#
#    status customerid
# 0   Sold      C0028
# 1   Sold      C0027
# 2   Sold      C0112

# %%
properties.dtypes
# Out:
# id                    object
# building              object
# date_sale     datetime64[ns]
# type                  object
# property#             object
# area                 float64
# price                 object
# status                object
# customerid            object
# dtype: object

# %%
# create a new column called price$ that dont have the $ sign
properties['price$'] = properties['price'].str.strip('$')

properties.head(3)
# Out:
#      id building  date_sale       type property#    area         price  \
# 0  1030        1 2005-11-01  apartment        30  743.09  $246,172.68
# 1  1029        1 2005-10-01  apartment        29  756.21  $246,331.90
# 2  2002        2 2007-07-01  apartment         2  587.28  $209,280.91
#
#    status customerid       price$
# 0   Sold      C0028   246,172.68
# 1   Sold      C0027   246,331.90
# 2   Sold      C0112   209,280.91

# %%
# replace the , with empty string in price$ add the regex = True
properties['price$'] = properties['price$'].replace(',', '', regex = True)

# %%
# cast the price into float
properties['price$'] = properties['price$'].astype(float)

# %%
# drop the price column
properties = properties.drop(columns = ['price'])

# %%
properties.head(3)
# Out:
#      id building  date_sale       type property#    area  status customerid  \
# 0  1030        1 2005-11-01  apartment        30  743.09   Sold      C0028
# 1  1029        1 2005-10-01  apartment        29  756.21   Sold      C0027
# 2  2002        2 2007-07-01  apartment         2  587.28   Sold      C0112
#
#       price$
# 0  246172.68
# 1  246331.90
# 2  209280.91

# %%
properties.dtypes
# Out:
# id                    object
# building              object
# date_sale     datetime64[ns]
# type                  object
# property#             object
# area                 float64
# status                object
# customerid            object
# price$               float64
# dtype: object

# %%
properties['status'].unique()
# Out:
# array([' Sold ', '-'], dtype=object)

# %%
# remove the leading and trailing white spaces in the status column
properties['status'] = properties['status'].str.strip()

# lower case the status column
properties['status'] = properties['status'].str.lower()

properties['status'].unique()
# Out:
# array(['sold', '-'], dtype=object)

# %%
# rename the status column to sold and convert the status column into boolean
properties = properties.rename(columns = {'status': 'sold'})

# the sold column is a boolean 1 = sold and 0 = not sold using map
properties['sold'] = properties['sold'].map({'sold': 1, '-': 0})

properties['sold'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
properties.dtypes
# Out:
# id                    object
# building              object
# date_sale     datetime64[ns]
# type                  object
# property#             object
# area                 float64
# sold                   int64
# customerid            object
# price$               float64
# dtype: object

# %%
# now let's check any mising values
properties.isnull().sum()
# Out:
# id             0
# building       0
# date_sale     72
# type           0
# property#      0
# area           0
# sold           0
# customerid    72
# price$         0
# dtype: int64

# %% [markdown]
# ## Customers dataset

# %%
customers = customers_raw_data.copy()

# %%
customers.columns.array
# Out:
# <NumpyExtensionArray>
# [ '\ufeffcustomerid',            'entity',              'name',
#            'surname',        'birth_date',               'sex',
#            'country',             'state',           'purpose',
#  'deal_satisfaction',          'mortgage',            'source']
# Length: 12, dtype: object

# %%
customers.columns.values
# Out:
# array(['\ufeffcustomerid', 'entity', 'name', 'surname', 'birth_date',
#        'sex', 'country', 'state', 'purpose', 'deal_satisfaction',
#        'mortgage', 'source'], dtype=object)

# %%
# rename the \ufeffcustomerid column to customerid
customers = customers.rename(columns = {'\ufeffcustomerid': 'customerid'})

customers.head(3)
# Out:
#   customerid      entity     name  surname  birth_date sex country  \
# 0      C0110  Individual   Kareem      Liu   5/11/1968   F     USA
# 1      C0010  Individual  Trystan  Oconnor  11/26/1962   M     USA
# 2      C0132  Individual     Kale      Gay    4/7/1959   M     USA
#
#         state purpose  deal_satisfaction mortgage   source
# 0  California    Home                  4      Yes  Website
# 1  California    Home                  1       No  Website
# 2  California    Home                  4      Yes   Agency

# %%
customers.describe(include='all')
# Out:
#        customerid      entity  name surname birth_date  sex country  \
# count         162         162   162     162        155  155     162
# unique        162           2   159     156        151    2       9
# top         C0110  Individual  Jack      Co  9/14/1966    M     USA
# freq            1         155     2       7          2   87     146
# mean          NaN         NaN   NaN     NaN        NaN  NaN     NaN
# std           NaN         NaN   NaN     NaN        NaN  NaN     NaN
# min           NaN         NaN   NaN     NaN        NaN  NaN     NaN
# 25%           NaN         NaN   NaN     NaN        NaN  NaN     NaN
# 50%           NaN         NaN   NaN     NaN        NaN  NaN     NaN
# 75%           NaN         NaN   NaN     NaN        NaN  NaN     NaN
# max           NaN         NaN   NaN     NaN        NaN  NaN     NaN
#
#              state purpose  deal_satisfaction mortgage   source
# count          154     162         162.000000      162      162
# unique           9       2                NaN        2        3
# top     California    Home                NaN       No  Website
# freq           100     112                NaN      102       93
# mean           NaN     NaN           3.456790      NaN      NaN
# std            NaN     NaN           1.333276      NaN      NaN
# min            NaN     NaN           1.000000      NaN      NaN
# 25%            NaN     NaN           3.000000      NaN      NaN
# 50%            NaN     NaN           4.000000      NaN      NaN
# 75%            NaN     NaN           5.000000      NaN      NaN
# max            NaN     NaN           5.000000      NaN      NaN

# %%
customers.dtypes
# Out:
# customerid           object
# entity               object
# name                 object
# surname              object
# birth_date           object
# sex                  object
# country              object
# state                object
# purpose              object
# deal_satisfaction     int64
# mortgage             object
# source               object
# dtype: object

# %%
# customers.isnull().sum()
customers.isna().sum()
# Out:
# customerid           0
# entity               0
# name                 0
# surname              0
# birth_date           7
# sex                  7
# country              0
# state                8
# purpose              0
# deal_satisfaction    0
# mortgage             0
# source               0
# dtype: int64

# %%
# rename the entity to individual
customers = customers.rename(columns = {'entity': 'individual'})
customers.head(3)
# Out:
#   customerid  individual     name  surname  birth_date sex country  \
# 0      C0110  Individual   Kareem      Liu   5/11/1968   F     USA
# 1      C0010  Individual  Trystan  Oconnor  11/26/1962   M     USA
# 2      C0132  Individual     Kale      Gay    4/7/1959   M     USA
#
#         state purpose  deal_satisfaction mortgage   source
# 0  California    Home                  4      Yes  Website
# 1  California    Home                  1       No  Website
# 2  California    Home                  4      Yes   Agency

# %%
# convert the individual column into boolean Individual = 1 and Company = 0
customers['individual'] = customers['individual'].map({'Individual': 1, 'Company': 0})

# %%
customers['individual'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
customers['sex'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
# convert the sex column into F: 1 and M: 0 and nan to pd.NA
customers['sex'] = customers['sex'].map({'F': '1', 'M': '0'}).fillna(pd.NA)

# %%
customers['sex'].unique()
# Out:
# array(['1', '0', <NA>], dtype=object)

# %%
customers.isna().sum()
# Out:
# customerid           0
# individual           0
# name                 0
# surname              0
# birth_date           7
# sex                  7
# country              0
# state                8
# purpose              0
# deal_satisfaction    0
# mortgage             0
# source               0
# dtype: int64

# %%
print(customers['source'].unique())
print('='*40)
print(customers['purpose'].unique())
# Out:
# ['Website' 'Agency' 'Client']
# ========================================
# ['Home' 'Investment']

# %%
# convert the source and purpose columns into lower case
customers['source'] = customers['source'].str.lower()
customers['purpose'] = customers['purpose'].str.lower()

# %%
customers.head(3)
# Out:
#   customerid  individual     name  surname  birth_date sex country  \
# 0      C0110           1   Kareem      Liu   5/11/1968   1     USA
# 1      C0010           1  Trystan  Oconnor  11/26/1962   0     USA
# 2      C0132           1     Kale      Gay    4/7/1959   0     USA
#
#         state purpose  deal_satisfaction mortgage   source
# 0  California    home                  4      Yes  website
# 1  California    home                  1       No  website
# 2  California    home                  4      Yes   agency

# %%
customers['mortgage'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# map mentage Yes = 1 and No = 0
customers['mortgage'] = customers['mortgage'].map({'Yes': 1, 'No': 0})

# %%
customers['mortgage'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
customers.isna().sum()
# Out:
# customerid           0
# individual           0
# name                 0
# surname              0
# birth_date           7
# sex                  7
# country              0
# state                8
# purpose              0
# deal_satisfaction    0
# mortgage             0
# source               0
# dtype: int64

# %%
# create a column called full name that concatenates the first name and last name
customers['full_name'] = customers['name'] + ' ' + customers['surname']

customers.head(3)
# Out:
#   customerid  individual     name  surname  birth_date sex country  \
# 0      C0110           1   Kareem      Liu   5/11/1968   1     USA
# 1      C0010           1  Trystan  Oconnor  11/26/1962   0     USA
# 2      C0132           1     Kale      Gay    4/7/1959   0     USA
#
#         state purpose  deal_satisfaction  mortgage   source        full_name
# 0  California    home                  4         1  website       Kareem Liu
# 1  California    home                  1         0  website  Trystan Oconnor
# 2  California    home                  4         1   agency         Kale Gay

# %%
# drop the two columns name and surname
customers = customers.drop(columns = ['name', 'surname'])

customers.head(3)
# Out:
#   customerid  individual  birth_date sex country       state purpose  \
# 0      C0110           1   5/11/1968   1     USA  California    home
# 1      C0010           1  11/26/1962   0     USA  California    home
# 2      C0132           1    4/7/1959   0     USA  California    home
#
#    deal_satisfaction  mortgage   source        full_name
# 0                  4         1  website       Kareem Liu
# 1                  1         0  website  Trystan Oconnor
# 2                  4         1   agency         Kale Gay

# %%
customers.dtypes
# Out:
# customerid           object
# individual            int64
# birth_date           object
# sex                  object
# country              object
# state                object
# purpose              object
# deal_satisfaction     int64
# mortgage              int64
# source               object
# full_name            object
# dtype: object

# %%
# convert birth_date to datetime
customers['birth_date'] = pd.to_datetime(customers['birth_date'])

customers.dtypes
# Out:
# customerid                   object
# individual                    int64
# birth_date           datetime64[ns]
# sex                          object
# country                      object
# state                        object
# purpose                      object
# deal_satisfaction             int64
# mortgage                      int64
# source                       object
# full_name                    object
# dtype: object

# %%
customers.isna().sum()
# Out:
# customerid           0
# individual           0
# birth_date           7
# sex                  7
# country              0
# state                8
# purpose              0
# deal_satisfaction    0
# mortgage             0
# source               0
# full_name            0
# dtype: int64

# %%
# combine the two datasets
combined_data = pd.merge(properties, customers, on = 'customerid', how = 'left')

# %%
combined_data.head(3)
# Out:
#      id building  date_sale       type property#    area  sold customerid  \
# 0  1030        1 2005-11-01  apartment        30  743.09     1     C0028
# 1  1029        1 2005-10-01  apartment        29  756.21     1     C0027
# 2  2002        2 2007-07-01  apartment         2  587.28     1     C0112
#
#       price$  individual birth_date  sex country state purpose  \
# 0  246172.68         NaN        NaT  NaN     NaN   NaN     NaN
# 1  246331.90         NaN        NaT  NaN     NaN   NaN     NaN
# 2  209280.91         NaN        NaT  NaN     NaN   NaN     NaN
#
#    deal_satisfaction  mortgage source full_name
# 0                NaN       NaN    NaN       NaN
# 1                NaN       NaN    NaN       NaN
# 2                NaN       NaN    NaN       NaN

# %% [markdown]
# it seem's there is problem with the key

# %%
customers['customerid'].unique()
# Out:
# array(['C0110', 'C0010', 'C0132', 'C0137', 'C0174', 'C0088', 'C0079',
#        'C0149', 'C0064', 'C0068', 'C0006', 'C0055', 'C0016', 'C0121',
#        'C0074', 'C0032', 'C0093', 'C0076', 'C0165', 'C0153', 'C0129',
#        'C0162', 'C0071', 'C0069', 'C0005', 'C0144', 'C0020', 'C0101',
#        'C0128', 'C0033', 'C0171', 'C0095', 'C0123', 'C0015', 'C0084',
#        'C0019', 'C0053', 'C0080', 'C0070', 'C0051', 'C0022', 'C0127',
#        'C0081', 'C0104', 'C0073', 'C0168', 'C0169', 'C0039', 'C0086',
#        'C0036', 'C0045', 'C0105', 'C0119', 'C0012', 'C0065', 'C0054',
#        'C0172', 'C0029', 'C0098', 'C0142', 'C0135', 'C0037', 'C0134',
#        'C0091', 'C0018', 'C0085', 'C0061', 'C0066', 'C0156', 'C0043',
#        'C0112', 'C0145', 'C0047', 'C0082', 'C0007', 'C0052', 'C0041',
#        'C0004', 'C0118', 'C0030', 'C0154', 'C0125', 'C0115', 'C0078',
#        'C0151', 'C0111', 'C0014', 'C0103', 'C0024', 'C0166', 'C0067',
#        'C0122', 'C0107', 'C0003', 'C0099', 'C0160', 'C0013', 'C0059',
#        'C0120', 'C0150', 'C0140', 'C0002', 'C0096', 'C0159', 'C0163',
#        'C0100', 'C0155', 'C0049', 'C0148', 'C0146', 'C0034', 'C0141',
#        'C0008', 'C0131', 'C0089', 'C0157', 'C0114', 'C0124', 'C0158',
#        'C0175', 'C0023', 'C0164', 'C0058', 'C0062', 'C0042', 'C0048',
#        'C0083', 'C0025', 'C0087', 'C0094', 'C0038', 'C0011', 'C0139',
#        'C0021', 'C0106', 'C0040', 'C0035', 'C0126', 'C0136', 'C0109',
#        'C0028', 'C0057', 'C0130', 'C0044', 'C0056', 'C0077', 'C0031',
#        'C0072', 'C0063', 'C0017', 'C0009', 'C0075', 'C0027', 'C0060',
#        'C0001', 'C0090', 'C0108', 'C0170', 'C0138', 'C0113', 'C0147',
#        'C0133'], dtype=object)

# %%
# remove white spacess in the customerid column
customers['customerid'] = customers['customerid'].str.strip()
properties['customerid'] = properties['customerid'].str.strip()

# %%
properties['customerid'] = np.where(properties['customerid'] == '', pd.NA, properties['customerid'])

# %%
real_estate_data = pd.merge(properties, customers, on = 'customerid', how = 'left')

# %%
real_estate_data.head()
# Out:
#      id building  date_sale       type property#     area  sold customerid  \
# 0  1030        1 2005-11-01  apartment        30   743.09     1      C0028
# 1  1029        1 2005-10-01  apartment        29   756.21     1      C0027
# 2  2002        2 2007-07-01  apartment         2   587.28     1      C0112
# 3  2031        2 2007-12-01  apartment        31  1604.75     1      C0160
# 4  1049        1 2004-11-01  apartment        49  1375.45     1      C0014
#
#       price$  individual birth_date sex country       state     purpose  \
# 0  246172.68         1.0 1986-06-21   1     USA  California        home
# 1  246331.90         1.0 1983-02-24   1     USA  California        home
# 2  209280.91         1.0 1985-12-27   0     USA  California        home
# 3  452667.01         1.0 1985-12-27   0     USA  California  investment
# 4  467083.31         1.0 1979-05-15   1     USA  California        home
#
#    deal_satisfaction  mortgage   source         full_name
# 0                5.0       0.0  website    Madalyn Mercer
# 1                5.0       0.0  website     Lara Carrillo
# 2                1.0       1.0   client   Donavan Flowers
# 3                3.0       1.0  website     Darien Dorsey
# 4                4.0       0.0   agency  Alessandra Perry

# %%
real_estate_data.tail()
# Out:
#        id building date_sale       type property#     area  sold customerid  \
# 262  5044        5       NaT  apartment        44  1238.58     0        NaN
# 263  5047        5       NaT  apartment        47   794.52     0        NaN
# 264  5048        5       NaT  apartment        48  1013.27     0        NaN
# 265  5050        5       NaT  apartment        50  1074.71     0        NaN
# 266  5051        5       NaT  apartment        51   789.25     0        NaN
#
#         price$  individual birth_date  sex country state purpose  \
# 262  322610.74         NaN        NaT  NaN     NaN   NaN     NaN
# 263  279191.26         NaN        NaT  NaN     NaN   NaN     NaN
# 264  287996.53         NaN        NaT  NaN     NaN   NaN     NaN
# 265  365868.78         NaN        NaT  NaN     NaN   NaN     NaN
# 266  199216.40         NaN        NaT  NaN     NaN   NaN     NaN
#
#      deal_satisfaction  mortgage source full_name
# 262                NaN       NaN    NaN       NaN
# 263                NaN       NaN    NaN       NaN
# 264                NaN       NaN    NaN       NaN
# 265                NaN       NaN    NaN       NaN
# 266                NaN       NaN    NaN       NaN

# %%
real_estate_data.fillna(pd.NA)
# Out:
#        id building  date_sale       type property#     area  sold customerid  \
# 0    1030        1 2005-11-01  apartment        30   743.09     1      C0028
# 1    1029        1 2005-10-01  apartment        29   756.21     1      C0027
# 2    2002        2 2007-07-01  apartment         2   587.28     1      C0112
# 3    2031        2 2007-12-01  apartment        31  1604.75     1      C0160
# 4    1049        1 2004-11-01  apartment        49  1375.45     1      C0014
# ..    ...      ...        ...        ...       ...      ...   ...        ...
# 262  5044        5        NaT  apartment        44  1238.58     0        NaN
# 263  5047        5        NaT  apartment        47   794.52     0        NaN
# 264  5048        5        NaT  apartment        48  1013.27     0        NaN
# 265  5050        5        NaT  apartment        50  1074.71     0        NaN
# 266  5051        5        NaT  apartment        51   789.25     0        NaN
#
#         price$  individual birth_date  sex country       state     purpose  \
# 0    246172.68         1.0 1986-06-21    1     USA  California        home
# 1    246331.90         1.0 1983-02-24    1     USA  California        home
# 2    209280.91         1.0 1985-12-27    0     USA  California        home
# 3    452667.01         1.0 1985-12-27    0     USA  California  investment
# 4    467083.31         1.0 1979-05-15    1     USA  California        home
# ..         ...         ...        ...  ...     ...         ...         ...
# 262  322610.74         NaN        NaT  NaN     NaN         NaN         NaN
# 263  279191.26         NaN        NaT  NaN     NaN         NaN         NaN
# 264  287996.53         NaN        NaT  NaN     NaN         NaN         NaN
# 265  365868.78         NaN        NaT  NaN     NaN         NaN         NaN
# 266  199216.40         NaN        NaT  NaN     NaN         NaN         NaN
#
#      deal_satisfaction  mortgage   source         full_name
# 0                  5.0       0.0  website    Madalyn Mercer
# 1                  5.0       0.0  website     Lara Carrillo
# 2                  1.0       1.0   client   Donavan Flowers
# 3                  3.0       1.0  website     Darien Dorsey
# 4                  4.0       0.0   agency  Alessandra Perry
# ..                 ...       ...      ...               ...
# 262                NaN       NaN      NaN               NaN
# 263                NaN       NaN      NaN               NaN
# 264                NaN       NaN      NaN               NaN
# 265                NaN       NaN      NaN               NaN
# 266                NaN       NaN      NaN               NaN
#
# [267 rows x 19 columns]

# %%
real_estate_data.dtypes
# Out:
# id                           object
# building                     object
# date_sale            datetime64[ns]
# type                         object
# property#                    object
# area                        float64
# sold                          int64
# customerid                   object
# price$                      float64
# individual                  float64
# birth_date           datetime64[ns]
# sex                          object
# country                      object
# state                        object
# purpose                      object
# deal_satisfaction           float64
# mortgage                    float64
# source                       object
# full_name                    object
# dtype: object

# %% [markdown]
# ### Statistics

# %%
data = real_estate_data.copy()

# %%
data.describe()
# Out:
#                            date_sale         area        sold         price$  \
# count                            195   267.000000  267.000000     267.000000
# mean   2006-11-08 14:38:46.153846272   936.221311    0.730337  281171.901386
# min              2004-03-01 00:00:00   410.710000    0.000000  117564.070000
# 25%              2006-04-16 00:00:00   756.210000    0.000000  217553.055000
# 50%              2007-03-01 00:00:00   798.280000    1.000000  249075.660000
# 75%              2007-09-01 00:00:00  1121.950000    1.000000  326964.855000
# max              2010-05-01 00:00:00  1942.500000    1.000000  538271.740000
# std                              NaN   284.894858    0.444618   89119.121005
#
#        individual                     birth_date  deal_satisfaction  \
# count  195.000000                            178         195.000000
# mean     0.912821  1961-01-08 11:35:43.820224704           3.600000
# min      0.000000            1931-02-13 00:00:00           1.000000
# 25%      1.000000            1951-05-04 06:00:00           3.000000
# 50%      1.000000            1962-09-23 00:00:00           4.000000
# 75%      1.000000            1970-07-09 06:00:00           5.000000
# max      1.000000            1986-06-21 00:00:00           5.000000
# std      0.282824                            NaN           1.340872
#
#          mortgage
# count  195.000000
# mean     0.317949
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000
# std      0.466878

# %%
data.describe(include='all')
# Out:
#           id building                      date_sale       type property#  \
# count    267      267                            195        267       267
# unique   240        5                            NaN          2        59
# top     5041        3                            NaN  apartment        34
# freq       2       63                            NaN        259         7
# mean     NaN      NaN  2006-11-08 14:38:46.153846272        NaN       NaN
# min      NaN      NaN            2004-03-01 00:00:00        NaN       NaN
# 25%      NaN      NaN            2006-04-16 00:00:00        NaN       NaN
# 50%      NaN      NaN            2007-03-01 00:00:00        NaN       NaN
# 75%      NaN      NaN            2007-09-01 00:00:00        NaN       NaN
# max      NaN      NaN            2010-05-01 00:00:00        NaN       NaN
# std      NaN      NaN                            NaN        NaN       NaN
#
#                area        sold customerid         price$  individual  \
# count    267.000000  267.000000        195     267.000000  195.000000
# unique          NaN         NaN        162            NaN         NaN
# top             NaN         NaN      C0174            NaN         NaN
# freq            NaN         NaN          9            NaN         NaN
# mean     936.221311    0.730337        NaN  281171.901386    0.912821
# min      410.710000    0.000000        NaN  117564.070000    0.000000
# 25%      756.210000    0.000000        NaN  217553.055000    1.000000
# 50%      798.280000    1.000000        NaN  249075.660000    1.000000
# 75%     1121.950000    1.000000        NaN  326964.855000    1.000000
# max     1942.500000    1.000000        NaN  538271.740000    1.000000
# std      284.894858    0.444618        NaN   89119.121005    0.282824
#
#                            birth_date  sex country       state purpose  \
# count                             178  178     195         181     195
# unique                            NaN    2       9           9       2
# top                               NaN    0     USA  California    home
# freq                              NaN  108     165         120     119
# mean    1961-01-08 11:35:43.820224704  NaN     NaN         NaN     NaN
# min               1931-02-13 00:00:00  NaN     NaN         NaN     NaN
# 25%               1951-05-04 06:00:00  NaN     NaN         NaN     NaN
# 50%               1962-09-23 00:00:00  NaN     NaN         NaN     NaN
# 75%               1970-07-09 06:00:00  NaN     NaN         NaN     NaN
# max               1986-06-21 00:00:00  NaN     NaN         NaN     NaN
# std                               NaN  NaN     NaN         NaN     NaN
#
#         deal_satisfaction    mortgage   source   full_name
# count          195.000000  195.000000      195         195
# unique                NaN         NaN        3         162
# top                   NaN         NaN  website  Marleez Co
# freq                  NaN         NaN      119           9
# mean             3.600000    0.317949      NaN         NaN
# min              1.000000    0.000000      NaN         NaN
# 25%              3.000000    0.000000      NaN         NaN
# 50%              4.000000    0.000000      NaN         NaN
# 75%              5.000000    1.000000      NaN         NaN
# max              5.000000    1.000000      NaN         NaN
# std              1.340872    0.466878      NaN         NaN

# %%
data['building'].unique()
# Out:
# array(['1', '2', '3', '4', '5'], dtype=object)

# %%
data.groupby('building').size()
# Out:
# building
# 1    52
# 2    57
# 3    63
# 4    43
# 5    52
# dtype: int64

# %%
data['type'].unique()
# Out:
# array(['apartment', 'office'], dtype=object)

# %%
data['country'].unique()
# Out:
# array(['USA', 'UK', 'USA ', 'Belgium', 'Russia', 'Denmark', 'Germany',
#        'Mexico', 'Canada', nan], dtype=object)

# %%
data['state'].unique()
# Out:
# array(['California', 'Virginia', 'Arizona', 'Oregon', 'Nevada',
#        'Colorado', 'Utah', nan, 'Kansas', 'Wyoming'], dtype=object)

# %%
data['deal_satisfaction'].unique()
# Out:
# array([ 5.,  1.,  3.,  4.,  2., nan])
